# %% [markdown]
# # Problem Statement

# %% [markdown]
# ## Importing required model

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ("Medical_diabetes_dataset.csv")

# %%
df.head ()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes  Pregnancies
# 0          6.6                  140         0            2
# 1          6.6                   80         0            2
# 2          5.7                  158         0            8
# 3          5.0                  155         0            5
# 4          4.8                  155         0            2

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
#  9   Pregnancies          100000 non-null  int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 7.6+ MB

# %% [markdown]
# ## Univariate Analysis

# %%
df.hist (bins = 15, color = "r", edgecolor = "black", xlabelsize = 8, ylabelsize = 8, 
        linewidth = 1, grid = False)

plt.tight_layout (rect = (0,0, 1.2,1.2))

plt.suptitle ("Diabetes Diagnosis Univariate analysis", x = 0.65, y = 1.25)
plt.show ()

# %% [markdown]
# ## Multivariate Analysis

# %%
corr = df.corr ()
corr
# Out:
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.251171       0.233354  0.337396
# hypertension         0.251171      1.000000       0.121262  0.147666
# heart_disease        0.233354      0.121262       1.000000  0.061198
# bmi                  0.337396      0.147666       0.061198  1.000000
# HbA1c_level          0.101354      0.080939       0.067589  0.082997
# blood_glucose_level  0.110672      0.084429       0.070066  0.091261
# diabetes             0.258008      0.197823       0.171727  0.214357
# Pregnancies          0.000150      0.000358       0.002138  0.000047
#
#                      HbA1c_level  blood_glucose_level  diabetes  Pregnancies
# age                     0.101354             0.110672  0.258008     0.000150
# hypertension            0.080939             0.084429  0.197823     0.000358
# heart_disease           0.067589             0.070066  0.171727     0.002138
# ...

# %%
plt.figure (figsize = (12, 10))

sns.heatmap (corr, annot = True, fmt = ".2f", cmap = "coolwarm_r", linewidth = 0.2)

plt.title ("Diabetes Diagnosis multivariate plot", fontsize = 14)
plt.show ()

# %%
# comparing the age and diabetes colummn
sns.boxplot (y = "age", x = "diabetes", data = df, palette = "colorblind")
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='age'>

# %% [markdown]
# **NB:you can see from the observation above that the older you get (55-80) the more prone you are to diabetes**

# %%
# comparing the blood_glucose_level and diabetes colummn
sns.boxplot (y = "blood_glucose_level", x = "diabetes", data = df, palette = "colorblind")
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='blood_glucose_level'>

# %% [markdown]
# **NB:you can see from the observation above that the higher your blood_glucose_level (150-300) the more prone you are to diabetes**

# %%
# comparing the HbA1c_level and diabetes colummn
sns.boxplot (y = "HbA1c_level", x = "diabetes", data = df, palette = "colorblind")
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='HbA1c_level'>

# %% [markdown]
# #### Observation:
# - Normal HbA1c_level is below 5.7%
# - HbA1c_level between 5.7% and 6.4% will suggest diabetes

# %% [markdown]
# ### Handling categorical Datas

# %%
df = pd.get_dummies (df, columns = ["smoking_history", "gender"])

# %%
df
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  Pregnancies  smoking_history_No Info  \
# 0                      140         0            2                        0
# 1                       80         0            2                        1
# ...

# %%
del df["gender_Other"]

# %%
df
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  Pregnancies  smoking_history_No Info  \
# 0                      140         0            2                        0
# 1                       80         0            2                        1
# ...

# %% [markdown]
# ## Modelling
#
# ### Splitting our dataset

# %%
x = df.drop ("diabetes", axis = 1)
y = df["diabetes"]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
x
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  Pregnancies  smoking_history_No Info  \
# 0                      140            2                        0
# 1                       80            2                        1
# ...

# %%
# Splitting our dataset into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x, y, train_size = 0.8, test_size = 0.2, random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((80000, 15), (20000, 15))

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression ()

# %%
model.fit (x_train, y_train)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict (x_test)

# %%
# Evaluating our model performance
from sklearn.metrics import confusion_matrix, accuracy_score
confusion_matrix (y_test, y_pred)
# Out:
# array([[18132,   160],
#        [ 1005,   703]], dtype=int64)

# %% [markdown]
# ### Readings
#
#
#
# -

# %%
accuracy_score (y_test, y_pred)
# Out:
# 0.94175
